# %%
from basic_data_inspection import *
from univariates_analysis import *
from missing_values import *
from bivariates_analysis import *
from multivariates_analysis import *

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = '../data/iris/iris.data'
df = pd.read_csv(data_path, sep=',', header=None)
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
missing = SimplMissingValuesAnalyser()
missing.identify_missing_values(df)
missing.plot_missing_values(df)
# Out:
# Missing Values:
# Series([], dtype: int64)

# %%
univariates = SimplUnivariatesAnalyser()

univariates.identify_univariates(df)
univariates.plot_univariates(df)
# Out:
# Univariates:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
FeaturesAnalysis = NumericalvsNumericalAnalysis()

FeaturesAnalysis.analyze(df, 'sepal_length', 'sepal_width')
FeaturesAnalysis.analyze(df, 'sepal_length', 'petal_length')
FeaturesAnalysis.analyze(df, 'sepal_length', 'petal_width')
FeaturesAnalysis.analyze(df, 'sepal_width', 'petal_length')
FeaturesAnalysis.analyze(df, 'sepal_width', 'petal_width')
FeaturesAnalysis.analyze(df, 'petal_length', 'petal_width')

# %%
PairPlot = PairplotAnalysis()
PairPlot.analyze(df)

Heatmap = HeatmapAnalysis()
Heatmap.analyze(df)
